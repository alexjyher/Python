# %% [markdown]
# # Automating Crypto Website API Pull Project

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '33a1ca1d-359e-4802-8d19-197f62d6bf70',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-09-08T07:55:28.343Z', 'error_code': 0, 'error_message': None, 'elapsed': 31, 'credit_count': 1, 'notice': None, 'total_count': 9229}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10449, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
# Out:
# C:\Users\alexj\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '33a1ca1d-359e-4802-8d19-197f62d6bf70',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    
    if not os.path.isfile(r'C:\Users\alexj\Downloads\Python Project"\API.csv'):
        df.to_csv(r'C:\Users\alexj\Downloads\Python Project\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\alexj\Downloads\Python Project\API.csv', mode='a', header=False)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# {'status': {'timestamp': '2023-09-08T07:55:42.908Z', 'error_code': 0, 'error_message': None, 'elapsed': 17, 'credit_count': 1, 'notice': None, 'total_count': 9229}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10449, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
df72 = pd.read_csv(r'C:\Users\alexj\Downloads\Python Project\API.csv')
df72
# Out:
#     Unnamed: 0     id         name symbol                  slug  \
# 0            0      1      Bitcoin    BTC               bitcoin
# 1            1   1027     Ethereum    ETH              ethereum
# 2            2    825  Tether USDt   USDT                tether
# 3            3   1839          BNB    BNB                   bnb
# 4            4     52          XRP    XRP                   xrp
# 5            5   3408     USD Coin   USDC              usd-coin
# 6            6   2010      Cardano    ADA               cardano
# 7            7     74     Dogecoin   DOGE              dogecoin
# 8            8   5426       Solana    SOL                solana
# 9            9   1958         TRON    TRX                  tron
# 10          10  11419      Toncoin    TON               toncoin
# 11          11   4943          Dai    DAI  multi-collateral-dai
# 12          12   6636     Polkadot    DOT          polkadot-new
# 13          13   3890      Polygon  MATIC               polygon
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

df
# Out:
#        id         name symbol                  slug  num_market_pairs  \
# 0       1      Bitcoin    BTC               bitcoin             10449
# 1    1027     Ethereum    ETH              ethereum              7352
# 2     825  Tether USDt   USDT                tether             61770
# 3    1839          BNB    BNB                   bnb              1614
# 4      52          XRP    XRP                   xrp              1065
# 5    3408     USD Coin   USDC              usd-coin             13979
# 6    2010      Cardano    ADA               cardano               929
# 7      74     Dogecoin   DOGE              dogecoin               781
# 8    5426       Solana    SOL                solana               505
# 9    1958         TRON    TRX                  tron               835
# 10  11419      Toncoin    TON               toncoin               137
# 11   4943          Dai    DAI  multi-collateral-dai              2566
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.13733                       1.91882
# Ethereum                         0.11313                       0.66760
# Tether USDt                      0.00243                      -0.00278
# BNB                              0.00441                       0.71538
# XRP                              0.09843                       0.63520
# USD Coin                        -0.00187                      -0.00585
# Cardano                          0.09013                       0.52997
# Dogecoin                         0.14571                       0.42165
# Solana                          -0.11729                       1.63547
# TRON                            -0.11846                       0.31558
# Toncoin                         -0.42350                      -3.25552
# Dai                              0.02645                      -0.00691
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      0.13733
#              quote.USD.percent_change_24h     1.91882
#              quote.USD.percent_change_7d      1.03590
#              quote.USD.percent_change_30d   -11.93075
#              quote.USD.percent_change_60d   -12.79608
#              quote.USD.percent_change_90d     2.21347
# Ethereum     quote.USD.percent_change_1h      0.11313
#              quote.USD.percent_change_24h     0.66760
#              quote.USD.percent_change_7d      0.02050
#              quote.USD.percent_change_30d   -11.56227
#              quote.USD.percent_change_60d   -11.27157
#              quote.USD.percent_change_90d    -5.21047
# Tether USDt  quote.USD.percent_change_1h      0.00243
#              quote.USD.percent_change_24h    -0.00278
#              quote.USD.percent_change_7d      0.00342
#              quote.USD.percent_change_30d    -0.00061
#              quote.USD.percent_change_60d    -0.06584
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    0.13733
#             quote.USD.percent_change_24h   1.91882
#             quote.USD.percent_change_7d    1.03590
#             quote.USD.percent_change_30d -11.93075
#             quote.USD.percent_change_60d -12.79608
#             quote.USD.percent_change_90d   2.21347
# Ethereum    quote.USD.percent_change_1h    0.11313
#             quote.USD.percent_change_24h   0.66760
#             quote.USD.percent_change_7d    0.02050
#             quote.USD.percent_change_30d -11.56227
#             quote.USD.percent_change_60d -11.27157
#             quote.USD.percent_change_90d  -5.21047
# Tether USDt quote.USD.percent_change_1h    0.00243
#             quote.USD.percent_change_24h  -0.00278
#             quote.USD.percent_change_7d    0.00342
#             quote.USD.percent_change_30d  -0.00061
#             quote.USD.percent_change_60d  -0.06584
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.13733
# 1       Bitcoin  quote.USD.percent_change_24h   1.91882
# 2       Bitcoin   quote.USD.percent_change_7d   1.03590
# 3       Bitcoin  quote.USD.percent_change_30d -11.93075
# 4       Bitcoin  quote.USD.percent_change_60d -12.79608
# 5       Bitcoin  quote.USD.percent_change_90d   2.21347
# 6      Ethereum   quote.USD.percent_change_1h   0.11313
# 7      Ethereum  quote.USD.percent_change_24h   0.66760
# 8      Ethereum   quote.USD.percent_change_7d   0.02050
# 9      Ethereum  quote.USD.percent_change_30d -11.56227
# 10     Ethereum  quote.USD.percent_change_60d -11.27157
# 11     Ethereum  quote.USD.percent_change_90d  -5.21047
# 12  Tether USDt   quote.USD.percent_change_1h   0.00243
# 13  Tether USDt  quote.USD.percent_change_24h  -0.00278
# 14  Tether USDt   quote.USD.percent_change_7d   0.00342
# 15  Tether USDt  quote.USD.percent_change_30d  -0.00061
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.13733
# 1       Bitcoin  quote.USD.percent_change_24h   1.91882
# 2       Bitcoin   quote.USD.percent_change_7d   1.03590
# 3       Bitcoin  quote.USD.percent_change_30d -11.93075
# 4       Bitcoin  quote.USD.percent_change_60d -12.79608
# 5       Bitcoin  quote.USD.percent_change_90d   2.21347
# 6      Ethereum   quote.USD.percent_change_1h   0.11313
# 7      Ethereum  quote.USD.percent_change_24h   0.66760
# 8      Ethereum   quote.USD.percent_change_7d   0.02050
# 9      Ethereum  quote.USD.percent_change_30d -11.56227
# 10     Ethereum  quote.USD.percent_change_60d -11.27157
# 11     Ethereum  quote.USD.percent_change_90d  -5.21047
# 12  Tether USDt   quote.USD.percent_change_1h   0.00243
# 13  Tether USDt  quote.USD.percent_change_24h  -0.00278
# 14  Tether USDt   quote.USD.percent_change_7d   0.00342
# 15  Tether USDt  quote.USD.percent_change_30d  -0.00061
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   0.13733
# 1       Bitcoin            24h   1.91882
# 2       Bitcoin             7d   1.03590
# 3       Bitcoin            30d -11.93075
# 4       Bitcoin            60d -12.79608
# 5       Bitcoin            90d   2.21347
# 6      Ethereum             1h   0.11313
# 7      Ethereum            24h   0.66760
# 8      Ethereum             7d   0.02050
# 9      Ethereum            30d -11.56227
# 10     Ethereum            60d -11.27157
# 11     Ethereum            90d  -5.21047
# 12  Tether USDt             1h   0.00243
# 13  Tether USDt            24h  -0.00278
# 14  Tether USDt             7d   0.00342
# 15  Tether USDt            30d  -0.00061
# 16  Tether USDt            60d  -0.06584
# 17  Tether USDt            90d  -0.11380
# 18          BNB             1h   0.00441
# 19          BNB            24h   0.71538
# 20          BNB             7d   1.28736
# 21          BNB            30d -11.41336
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
